# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib import rc

data= pd.read_csv('https://github.com/Explore-AI/Public-Data/blob/master/exports%20ZAR-USD-data.csv?raw=true',index_col=0)

# %%
data.columns=['X','Y']
data.head()
# Out:
#             X         Y
# 2008M01  7.01  39356.82
# 2008M02  7.66  46946.33
# 2008M03  7.97  51150.89
# 2008M04  7.79  56174.34
# 2008M05  7.62  56240.45

# %%
X=data.X.values
Y=data.Y.values

x_mean=np.mean(X)
y_mean=np.mean(Y)

m= sum((X-x_mean) * (Y-y_mean)) / sum((X-x_mean)**2)

c= y_mean - m * x_mean
print("Slope = ", m)
print("Intercept = ", c)
# Out:
# Slope =  5425.571548390257
# Intercept =  17874.73627988212

# %%
df = pd.read_csv('https://github.com/Explore-AI/Public-Data/blob/master/exports%20ZAR-USD-data.csv?raw=true', index_col=0)
df.columns = ['Y', 'X']
df.head()
# Out:
#             Y         X
# 2008M01  7.01  39356.82
# 2008M02  7.66  46946.33
# 2008M03  7.97  51150.89
# 2008M04  7.79  56174.34
# 2008M05  7.62  56240.45

# %%
# Extract values of X and Y as numpy arrays for mathematical operations
X = df.X.values
Y = df.Y.values

# Calculate mean of X and Y
x_bar = np.mean(X)
y_bar = np.mean(Y)

# Calculate the slope (m) of the regression line using the least squares method
m = sum((X - x_bar) * (Y - y_bar)) / sum((X - x_bar) ** 2)

# Calculate the intercept (c) of the regression line
c = y_bar - m * x_bar

# Output the calculated slope and intercept
print("Slope = ", m)
print("Intercept = ", c)
# Out:
# Slope =  0.000113507257658843
# Intercept =  1.8448114670426463

# %%
def gen_y(x_gen, m, c):
    y_gen=[]
    for x_i in x_gen:
        y_i=m*x_i+c
        y_gen.append(y_i)
    return y_gen

y_gen=m*data.X + c

# %%
np.mean(y_gen)
# Out:
# np.float64(1.8459560363931236)

# %%
plt.scatter(data.X, data.Y)
plt.plot(data.X, y_gen, color='red')
plt.show()

# %%
errors2 = np.array(y_gen - df.Y) # Calculate the residuals by subtracting the observed Y values from the generated Y values
print(np.round(errors2, 2))
# Out:
# [ -5.16  -5.81  -6.12  -5.94  -5.77  -6.07  -5.78  -5.81  -6.21  -7.89
#   -8.25  -8.12  -8.05  -8.16  -8.62  -7.15  -6.53  -6.2   -6.1   -6.09
#   -5.67  -5.63  -5.67  -5.63  -5.61  -5.82  -5.56  -5.5   -5.8   -5.78
#   -5.68  -5.45  -5.28  -5.06  -5.13  -4.99  -5.07  -5.32  -5.07  -4.89
#   -5.02  -4.95  -4.95  -5.22  -5.72  -6.12  -6.28  -6.33  -6.16  -5.81
#   -5.76  -5.98  -6.3   -6.54  -6.4   -6.43  -6.42  -6.78  -6.94  -6.79
#   -6.94  -7.04  -7.34  -7.26  -7.52  -8.18  -8.05  -8.24  -8.13  -8.06
#   -8.35  -8.53  -9.04  -9.13  -8.9   -8.7   -8.56  -8.82  -8.85  -8.81
#   -9.13  -9.22  -9.25  -9.61  -9.72  -9.73 -10.22 -10.16 -10.12 -10.45
#  -10.61 -11.07 -11.76 -11.66 -12.27 -13.14 -14.52 -13.92 -13.54 -12.77
#  -13.53 -13.23 -12.56 -11.91 -12.17 -12.12 -12.07 -11.99 -11.69 -11.41
#  -11.09 -11.66 -11.44 -11.07 -11.28 -11.38 -11.31 -11.86 -12.21 -11.4 ]

# %%
plt.hist(errors2)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
X=df.X.values[:,np.newaxis]

# %%
lm.fit(X,df.Y)
# Out:
# LinearRegression()

# %%
m=lm.coef_[0]
c=lm.intercept_
print(m, c)
# Out:
# 0.00011350725765884303 1.8448114670426445

# %%
y_gen=lm.predict(X)

# %%
plt.scatter(X,df.Y)
plt.plot(X,y_gen, color='red')
plt.xlabel('Value of exports')
plt.ylabel('USD')
plt.show()

# %%
from sklearn import metrics

# %%
print('MSE', metrics.mean_squared_error(df.Y - gen_y))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 print('MSE', metrics.mean_squared_error(df.Y - gen_y))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:6135, in Series._arith_method(self, other, op)
#    6133 def _arith_method(self, other, op):
#    6134     self, other = self._align_for_op(other)
# ...

# %%
print('R2',metric.r_scores(df.X, df.Y)
