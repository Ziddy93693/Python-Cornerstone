# %%
# IMPORT DATASET
import pandas as pd
data=pd.read_csv('python_learning_exam_performance.csv')
data
# Out:
#       student_id  age    country prior_programming_experience  \
# 0              1   54   Pakistan                     Beginner
# 1              2   44    Nigeria                          NaN
# 2              3   30      India                 Intermediate
# 3              4   23    Nigeria                     Beginner
# 4              5   36         UK                          NaN
# ...          ...  ...        ...                          ...
# 2995        2996   39     Brazil                          NaN
# 2996        2997   34  Indonesia                 Intermediate
# 2997        2998   52   Pakistan                     Beginner
# 2998        2999   54   Pakistan                 Intermediate
# 2999        3000   36   Pakistan                     Advanced
#
#       weeks_in_course  hours_spent_learning_per_week  \
# 0                  12                           12.2
# 1                  15                           14.2
# 2                   5                            7.7
# ...

# %%
# CLEANNING
data.shape
# Out:
# (3000, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   student_id                         3000 non-null   int64
#  1   age                                3000 non-null   int64
#  2   country                            3000 non-null   object
#  3   prior_programming_experience       1938 non-null   object
#  4   weeks_in_course                    3000 non-null   int64
#  5   hours_spent_learning_per_week      3000 non-null   float64
#  6   practice_problems_solved           3000 non-null   int64
#  7   projects_completed                 3000 non-null   int64
#  8   tutorial_videos_watched            3000 non-null   int64
#  9   uses_kaggle                        3000 non-null   int64
#  10  participates_in_discussion_forums  3000 non-null   int64
# ...

# %%
data.describe()
# Out:
#         student_id          age  weeks_in_course  \
# count  3000.000000  3000.000000      3000.000000
# mean   1500.500000    35.327000         8.121000
# std     866.169729    11.302182         4.275019
# min       1.000000    16.000000         1.000000
# 25%     750.750000    26.000000         5.000000
# 50%    1500.500000    36.000000         8.000000
# 75%    2250.250000    45.000000        12.000000
# max    3000.000000    54.000000        15.000000
#
#        hours_spent_learning_per_week  practice_problems_solved  \
# count                    3000.000000               3000.000000
# mean                        7.035267                 59.983667
# std                         2.936134                  7.713056
# min                         0.000000                 35.000000
# 25%                         5.000000                 55.000000
# 50%                         7.000000                 60.000000
# 75%                         9.000000                 65.000000
# ...

# %%
data.isna().sum()
# Out:
# student_id                              0
# age                                     0
# country                                 0
# prior_programming_experience         1062
# weeks_in_course                         0
# hours_spent_learning_per_week           0
# practice_problems_solved                0
# projects_completed                      0
# tutorial_videos_watched                 0
# uses_kaggle                             0
# participates_in_discussion_forums       0
# debugging_sessions_per_week             0
# self_reported_confidence_python         0
# final_exam_score                        0
# passed_exam                             0
# dtype: int64

# %%
data_mean= data.groupby('prior_programming_experience')['weeks_in_course'].mean()
data_mean
# Out:
# prior_programming_experience
# Advanced        8.459259
# Beginner        7.969052
# Intermediate    8.219243
# Name: weeks_in_course, dtype: float64
